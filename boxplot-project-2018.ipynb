# %% [markdown]
# ## Fundamentals of Data Analysis - Project 2018

# %% [markdown]
# ## Introduction
# The aim of this project is to analyse a dataset and demonstrate the use of boxplot diagrams for visualising datasets graphically. I decided to use the Iris dataset as it is preloaded in the Python Seaborn library and it is also a very clean dataset. The Iris dataset is perfect for demonstrating the use of boxplot diagrams as it is made up of quantitative (numerical) data.

# %% [markdown]
# ## Iris Dataset
#
# The Iris data set, also known as Fisher's Iris data set, consists of 50 samples from each of the following three species of Iris:
#
# - Iris Setosa
# - Iris Virginica
# - Iris Versicolor
#
# This data set was introduced by British statistician and biologist Ronald Fisher in 1936. The sepal length, sepal width, petal length and petal width were measured in centimetres and recorded. From this data Fisher developed a linear discriminant model to distinguish the species from each other based on the four features measured.

# %% [markdown]
# ## Boxplots
#
# The “Box and Whisker Plot” was first introduced by Mathematician John Tukey in 1969. It is a visual diagram which shows the 'Five Number Summary' of any given data set. The five number summary includes the following values:
#
# - Minimum value
# - First quartile value
# - Median value
# - Third quartile value
# - Maximum value
#
# A boxplot or box and whisker plot, is a type of graph used to display patterns of quantitative (numerical) data. A boxplot splits a data set into quartiles. The body of the boxplot is a box, which goes from quartile 1 to quartile 3. Within the box, a horizontal line is drawn at quartile 2 which is the median of the data set. Two vertical lines, called whiskers, extend from the bottom and top of the box. The bottom whisker goes from quartile 1 to the smallest outlier in the data set, and the top whisker goes from quartile 3 to the largest outlier in the dataset. An outlier is a value that is abnormal in comparison to the other values in the dataset and is represented by a dot on a boxplot diagram. An analyst may decide to remove the outlier or outliers from the dataset.
#
#
# EXPLAIN RANGE and INTERQUARTILE RANGE and ADD an IMAGE

# %% [markdown]
# ## Python Libraries
#
# Python has a large number of libraries which makes it a powerful programming language for analysing data. The libraries that were imported and used in this project were Pandas, Matplotlib and Seaborn. Pandas is excellent for satistically analysing a dataset and matplotlib and seaborn provide the tools to visualise the dataset graphically.
#
# - Pandas - a data processing library which provides tools for shaping, merging, reshaping, and slicing data sets.
# - Matplotlib - a graphing library to create 2D plots and graphs on a variety of data formats.
# - Seaborn library - a plotting and styling library.

# %%
# import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data:
#
# As the 'Iris' dataset is preloaded in the Python Seaborn library, I can directly import the dataset from Seaborn rather than downloading the csv file from an external website. The iris dataset is made of 150 rows and 5 columns. It is a small, clean and well-known dataset used for machine learning projects.

# %%
# import the'iris' dataset from Seaborn
df_iris = sns.load_dataset('iris')

# %%
# Show the tips dataset
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %% [markdown]
# ## Summary Statistics
#
# Summary statistics describe the contents of the dataset.......

# %%
# Show the columns that make up the dataset
df_iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Show the first six rows of the entire dataset
df_iris.head(6)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
# Show the first six rows of the entire dataset
df_iris.tail(6)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# Print how many samples we have of each specie - it is an equal data set comprising of three species and 50 samples
print(df_iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
# Group data by species to enable a statistical analysis of each type of Iris
specie = df_iris.groupby('species')
# Create a for loop to group by specie
for name, group in specie:
  print('\n\n',name)
# Print statistical analysis for each specie of Iris  
  print(group.describe().round(2))
# Out:
#  setosa
#        sepal_length  sepal_width  petal_length  petal_width
# count         50.00        50.00         50.00        50.00
# mean           5.01         3.43          1.46         0.25
# std            0.35         0.38          0.17         0.11
# min            4.30         2.30          1.00         0.10
# 25%            4.80         3.20          1.40         0.20
# 50%            5.00         3.40          1.50         0.20
# 75%            5.20         3.68          1.58         0.30
# max            5.80         4.40          1.90         0.60
#
#
#  versicolor
#        sepal_length  sepal_width  petal_length  petal_width
# count         50.00        50.00         50.00        50.00
# mean           5.94         2.77          4.26         1.33
# std            0.52         0.31          0.47         0.20
# min            4.90         2.00          3.00         1.00
# 25%            5.60         2.52          4.00         1.20
# ...

# %%
# plot a boxplot to show the total bill amounts on a given day
df_iris = sns.boxplot(x="species", y="sepal_length", data=df_iris)

# %% [markdown]
# ### Boxplot Conclusion
#
# The boxplots generated above show the 5 summary numbers for each species and their sepal length. The only outlier visible is on the Virginica's sepal length.

# %% [markdown]
# ## References
#
# https://stattrek.com/statistics/charts/boxplot.aspx
#
#
# https://machinelearningmastery.com/machine-learning-in-python-step-by-step/
#
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
#
# https://seaborn.pydata.org/introduction.html
#
#
# https://www.wintellect.com/visualizing-sales-data-in-python-with-matplotlib/
#
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial
#
#
# https://en.wikipedia.org/wiki/Iris_flower_data_set
