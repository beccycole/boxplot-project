# %% [markdown]
# # Fundamentals of Data Analysis - Project 2018

# %% [markdown]
# ## Introduction
# The aim of this project is to analyse a dataset and demonstrate the use of boxplot diagrams for visualising datasets graphically. I have decided to use the Iris dataset for analysis as it is preloaded in the Python Seaborn library and it is also a very clean dataset. The Iris dataset is perfect for demonstrating the use of boxplot diagrams as it is made up of quantitative (numerical) data.

# %% [markdown]
# ## Iris Dataset
#
# The Iris data set, also known as Fisher's Iris data set, consists of 50 samples from each of the following three species of Iris:
#
# - Iris Setosa
# - Iris Virginica
# - Iris Versicolor
#
# This data set was introduced by British statistician and biologist Ronald Fisher in 1936. The sepal length, sepal width, petal length and petal width were measured in centimetres and recorded. From this data Fisher developed a linear discriminant model to distinguish the species from each other based on the four features measured.
#
# ![Fisher](https://upload.wikimedia.org/wikipedia/commons/4/46/R._A._Fischer.jpg)

# %% [markdown]
# ## Boxplots
#
# The “Box and Whisker Plot” was first introduced by Mathematician John Tukey in 1969. It is a visual diagram which shows the 'Five Number Summary' of any given data set - the distribution of the data. The five number summary includes the following values:
#
# - Minimum value
# - First quartile value
# - Median value
# - Third quartile value
# - Maximum value
#
# ![boxplot](http://www.physics.csbsju.edu/stats/simple.box.defs.gif)
#
# A boxplot or box and whisker plot, is a type of graph used to display patterns of quantitative (numerical) data. A boxplot splits a data set into quartiles. The body of the boxplot is a box, which goes from quartile 1 to quartile 3. Within the box, a horizontal line is drawn at quartile 2 which is the median of the data set. Two vertical lines, called whiskers, extend from the bottom and top of the box. The bottom whisker goes from quartile 1 to the minimum value in the data set, and the top whisker goes from quartile 3 to the maximum value in the dataset.
#
# A boxplot diagram also shows the presence of any outliers in a dataset. An outlier is a value that is abnormal in comparison to the other values in the dataset and is represented on the boxplot diagram by a filled circle. A suspected outlier is represented by an unfilled circle.
#
# Two other measures of statistical dispersion can also be measured from the boxplot diagram - the range and the interquartile range.
#
# The range is the distance between the minimum and maximum value on the boxplot diagram (if outliers are disregarded), or else it is the distance between the smallest outlier to the largest outlier (if outliers are not disregarded). The greater the value of the range, the greater the spread in the data as the range is based solely on the two most extreme points in the dataset.
#
# A boxplot diagram breaks a dataset up into quarters. The interquartile range (IQR) or the mid-spread is found by deducting quartile 1 from quartile 3 (Q3-Q1). The interquartile range is not affected by any outliers in the dataset. Again, the greater the value of the IQR, the greater the variance or spread in the dataset.

# %% [markdown]
# ## Python Libraries
#
# Python has a large number of libraries which makes it a powerful programming language for analysing data. The libraries that were imported and used in this project were Pandas, Matplotlib and Seaborn. Pandas is excellent for satistically analysing a dataset and matplotlib and seaborn provide the tools to visualise the dataset graphically.
#
# - Pandas - a data processing library which provides tools for shaping, merging, reshaping, and slicing data sets.
# - Matplotlib - a graphing library to create 2D plots and graphs on a variety of data formats.
# - Seaborn library - a plotting and styling library.

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data:
#
# As the 'Iris' dataset is preloaded in the Python Seaborn library, I can directly import the dataset from Seaborn rather than downloading the csv file from an external website. The iris dataset is made of 150 rows and 5 columns. It is a small, clean and well-known dataset used for machine learning projects.

# %%
# import the'iris' dataset from Seaborn
df = sns.load_dataset('iris')

# %%
# Show the iris dataset
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %% [markdown]
# ## Summary Statistics
#
# Summary statistics describe the contents of a dataset using numbers - they describe the distribution of the data. There is little variation in the sepal length, sepal width, petal length and petal width for each specie of Iris specie. The distribution of data is not widely spread, the data points are quite close together. This is shown below in the summary statistics for each specie of Iris.

# %%
# Show the columns that make up the dataset
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Show the first six rows of the entire iris dataset
df.head(6)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
# Show the last six rows of the entire dataset
df.tail(6)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# Print how many samples we have of each specie - it is an equal data set comprising of three species and 50 samples
print(df.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
# Group data by species to enable a statistical analysis of each type of Iris
specie = df.groupby('species')
# Create a for loop to group by specie
for name, group in specie:
  print('\n\n',name)
# Print statistical analysis for each specie of Iris  
  print(group.describe().round(2))
# Out:
#  setosa
#        sepal_length  sepal_width  petal_length  petal_width
# count         50.00        50.00         50.00        50.00
# mean           5.01         3.43          1.46         0.25
# std            0.35         0.38          0.17         0.11
# min            4.30         2.30          1.00         0.10
# 25%            4.80         3.20          1.40         0.20
# 50%            5.00         3.40          1.50         0.20
# 75%            5.20         3.68          1.58         0.30
# max            5.80         4.40          1.90         0.60
#
#
#  versicolor
#        sepal_length  sepal_width  petal_length  petal_width
# count         50.00        50.00         50.00        50.00
# mean           5.94         2.77          4.26         1.33
# std            0.52         0.31          0.47         0.20
# min            4.90         2.00          3.00         1.00
# 25%            5.60         2.52          4.00         1.20
# ...

# %% [markdown]
# ### Summary Statistics Conclusion
#
# The summary statistics shown above give the analyst a good indication of how the data is distributed for each specie of Iris and the four characteristics that were measured for each specie - sepal length, sepal width, petal length and petal width. It can be seen at a glance that for the three species of Iris the count is 50, which means 50 samples were measured for Setosa, Versicolor and Virginica. The standard deviation for each feature measured for the three species of Iris, is relatively low, which indicates the measurements are very close to the mean values. The descriptive statistics also show the mean, minimum, first quartile, median, third quartile and maximum values. This data would be much easier to analyse by using visual means such as boxplot diagrams.

# %% [markdown]
# ## Boxplot Diagrams

# %%
# plot a boxplot to show the distribution of data for the sepal length for each specie of iris
df = sns.boxplot(x="species", y="sepal_length", data=df)

# %% [markdown]
# ### Overview of Sepal Length
#
# - Sepal length increases in size from Setosa to Virginica.
# - One minimum outlier can be seen on the Virginica boxplot diagram.
# - The versicolor and Virginica boxplots are both slightly skewed right - the mean is greater than the median.
# - The Setosa boxplot is symmetric - the median is equal to the mean.
# - The range value for the Setosa Iris is the lowest and for the Virginica is the highest. Thus, the data is more widely spread for the Virginica Iris.
# - The IQR for the three species increases from Setosa to Virginica which is another indication that the data is more widely spread for the Versicolor and Virginica.

# %%
# plot a boxplot to show the distribution of data for the sepal width for each specie of iris
df = sns.load_dataset("iris")
df = sns.boxplot(x="species", y="sepal_width", data=df)

# %% [markdown]
# ### Overview of Sepal Width
# - Setosa has the largest sepal width.
# - Both minimum and maximum outliers can be seen on both the Setosa and Virginica boxplot diagrams.
# - The Setosa boxplot is skewed right - the median is greater than the mean.
# - The Versicolor boxplot is skewed left - the mean value is lower than the median.
# - The Virginica boxplot is symmetric - the mean and median are equal.
# - The range is lowest for the Virginica and highest for Setosa.
# - The IQR is lowest for Virginica - the data for the sepal width is less widely spread in comparison to the other two species.

# %%
# plot a boxplot to show the distribution of data for the petal length for each specie of iris
df = sns.load_dataset("iris")
df = sns.boxplot(x="species", y="petal_length", data=df)

# %% [markdown]
# ### Overview of Petal Length
# - Petal length increases in size from Setosa to Virginica.
# - One minimum outlier can be seen on the Versicolor boxplot diagram.
# - Minimum and maximum outliers can be seen on the Setosa boxplot diagram but they are tightly bunched together.
# - The Setosa boxplot is skewed left - the mean value is lower than the median.
# - The Versicolor boxplot is symmetric - the mean and median are equal.
# - The Virginica boxplot is skewed left - the mean value is lower than the median.
# - The range values increase from Setosa to Virginica - the spread of the data for petal length is lowest for Setosa and highest for Virginica.
# - The IQR follows the same pattern as the range - the IQR is lowest for Setosa and greatest for Virginica - the spead of the data increases from Setosa to Virginica.

# %%
# plot a boxplot to show the distribution of data for the petal width for each specie of iris
df = sns.load_dataset("iris")
df = sns.boxplot(x="species", y="petal_width", data=df)

# %% [markdown]
# ### Overview of Petal Width
# - Petal width increases in size from Setosa to Virginica.
# - Setosa has the smallest petal width.
# - Virginica has the largest petal width.
# - Two maximum outliers can be seen on the Setosa boxplot diagram.
# - The Setosa boxplot is skewed right - the mean value is greater than the median.
# - The Versicolor boxplot is skewed right - the mean value is greater than the median.
# - The Virginica boxplot is skewed skewed right - the mean value is greater than the median.
# - The range values increase from Setosa to Virginica - the spread of the data for petal width is lowest for Setosa and highest for Virginica.
# - The IQR follows the same pattern as the range - the IQR is lowest for Setosa and greatest for Virginica - the spead of the data increases from Setosa to Virginica

# %% [markdown]
# ### Boxplot Conclusion
#
# The boxplots generated above show the 5 summary numbers for each species of Iris and the four characteristics measured - sepal length, sepal width, petal length and petal width.
# Boxplots can be summarised as follows:
# - The larger the IQR the greater the spread in the data.
# - Symmetric datasets show the median in the middle of the box. The distribution of the data is equally balanced around the mean.
# - If the longer part of the box is above the median the dataset is skewed right. The median is closer to the first quartile.
# - If the longer part of the box is below the median the dataset is skewed left. The median is closer to the third quartile.
# - If one side of the box is longer this indicates a greater spread in the data.
# - The data collected for the three species of Iris is not highly spread, therefore the data collected for each specie is very similar.

# %% [markdown]
# # Scatter Plot Diagrams
#
# A scatter plot is another type of mathematical diagram which is useful for displaying data. It is used to display data with two variables and is very useful for visualising any relationships between the variables. I created two scatter plot diagrams to compare sepal length and width for each specie of Iris and petal length and width for each specie of Iris. Scatter plots are a very important mathematical diagram as they can clearly show clusters of data points - clear distinct groups.

# %%
df = sns.load_dataset("iris")
# plot scatter plot using pandas - comparing sepal length and sepal width for the three species of iris
# Plot Setosa sepal length and width in red
ax = df[df.species=='setosa'].plot.scatter(x='sepal_length', y='sepal_width', color='red', label='setosa')
# Plot Versicolor sepal length and width in green
df[df.species=='versicolor'].plot.scatter(x='sepal_length', y='sepal_width', color='green', label='versicolor', ax=ax) 
# Plot Virginica sepal length and width in blue
df[df.species=='virginica'].plot.scatter(x='sepal_length', y='sepal_width', color='blue', label='virginica', ax=ax)
# Title of scatter plot
ax.set_title("Sepal Length and Width Comparison")
# Out:
# Text(0.5,1,'Sepal Length and Width Comparison')

# %% [markdown]
# ### Overview of Scatter Plot
# The three species have different sepal sizes. Setosa (red dots) can clearly be identified from this scatter plot, whereas Versicolor and Virginica (green and blue dots respectively) are more similar in size and not as clustered as the Setosa.

# %%
# plot a scatter plot - comparing petal length and petal width for three species
# Plot Setosa petal length and width in red
ax = df[df.species=='setosa'].plot.scatter(x='petal_length', y='petal_width', color='red', label='setosa')
# Plot Versicolor petal length and width in green
df[df.species=='versicolor'].plot.scatter(x='petal_length', y='petal_width', color='green', label='versicolor', ax=ax) 
# Plot Virginica petal length and width in blue
df[df.species=='virginica'].plot.scatter(x='petal_length', y='petal_width', color='blue', label='virginica', ax=ax) 
# show title
ax.set_title("Petal Length and Width Comparison")
# Out:
# Text(0.5,1,'Petal Length and Width Comparison')

# %% [markdown]
# ### Overview of Scatter Plot
# The three species have very different petal sizes but are highly correlated over each species. The Setosa (red dots) petals are much smaller than Versicolor and Virginica (green and blue dots respectively). The petal size for each specie are clearly grouped in the above scatter plot.

# %% [markdown]
# ## Scatter Plot Conclusion
#
# The scatter plots created above show that the Setosa Iris can be clearly identified as the data points are clustered tightly together for both comparisons - sepal length and sepal width and petal length and petal width. The Versicolor and Virginica data points are grouped for their petal length and petal width, there are distinct clusters, however these two types of Iris can not be clearly identified when the sepal length and sepal width are compared. The Setosa Iris is the most easily identified specie of Iris.

# %% [markdown]
# ## Conclusion
# There are many mathematical diagrams that can be created to display data points. Boxplots are useful for visualising the spread of the data and scatter plots are good for comparing two variables from a dataset.
# The boxplot diagrams on the Iris dataset show the variation in the data points for each specie of Iris and each characteristic - the extent to which the data points are dispersed.
# The scatter plot diagrams compare two variables for each specie of Iris and show how the data points are grouped.

# %% [markdown]
# ## References
#
# https://stattrek.com/statistics/charts/boxplot.aspx
#
#
# https://machinelearningmastery.com/machine-learning-in-python-step-by-step/
#
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
#
# https://seaborn.pydata.org/introduction.html
#
#
# https://www.wintellect.com/visualizing-sales-data-in-python-with-matplotlib/
#
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial
#
#
# https://en.wikipedia.org/wiki/Iris_flower_data_set
#
#
# http://www.physics.csbsju.edu/stats/box2.html
#
#
# https://www.khanacademy.org/math/cc-eighth-grade-math/cc-8th-data/cc-8th-interpreting-scatter-plots/a/clusters-in-scatter-plots
