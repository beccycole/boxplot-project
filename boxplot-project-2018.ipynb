# %% [markdown]
# ## Fundamentals of Data Analysis - Project 2018

# %% [markdown]
# ## Introduction
#
# The aim of this aproject is to analyse a dataset using box plots. I have chosen to use the 'Tips' dataset that is preloaded in the Seaborn library. It is a clean dataset and perfect for demonstrating the use of boxplot diagrams as it is made up of quantitative data.

# %% [markdown]
# ## Boxplots
#
# A boxplot or box and whisker plot, is a type of graph used to display patterns of quantitative (numerical) data. A boxplot splits a data set into quartiles. The body of the boxplot is a box, which goes from quartile 1 to quartile 3. Within the box, a horizontal line is drawn at quartile 2 which is the median of the data set. Two vertical lines, called whiskers, extend from the bottom and top of the box. The bottom whisker goes from quartile 1 to the smallest non-outlier in the data set, and the top whisker goes from quartile 3 to the largest non-outlier.
#
# # ADD IMAGE and reword and more info such as range etc

# %% [markdown]
# ## Python Libraries
#
# Python has a large number of libraries which makes it a powerful programming language for analysing data. The libraries that were imported and used in this project were Pandas and Matplotlib. I found that these two libraries, provided the tools, for me to easily and efficiently analyse the data.
#
# - Pandas - a data processing library which provides tools for shaping, merging, reshaping, and slicing data sets.
# - Matplotlib - a graphing library to create 2D plots and graphs on a variety of data formats.
# - Seaborn library - a plotting and styling library.

# %%
# import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data:
#
# The 'Tips' dataset will be imported from the Python library Seaborn. The tips dataset is made of 244 rows and 7 columns.

# %%
# import the'tips' dataset from Seaborn
df_tips = sns.load_dataset('tips')

# %%
# Show the tips dataset
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# ## Summary Statistics

# %%
# Show the columns that make up the dataset
df_tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# Show the first six rows of the entire dataset
df_tips.head(6)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %%
# Show the first six rows of the entire dataset
df_tips.tail(6)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# Show how many male and females are in the dataset
df_tips.groupby('sex').size()
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
# show how many people ate lunch or dinner on a particular day
df_tips.groupby('day').size()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# dtype: int64

# %%
# Calculate summary statistics on the dataset
df_tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# plot a boxplot to show the total bill amounts on a given day
df_tips = sns.boxplot(x="day", y="total_bill", data=df_tips)

# %% [markdown]
# ### Boxplot Conclusion
#
# The boxplots generated for each day all show outliers.

# %% [markdown]
# ## References
#
# https://stattrek.com/statistics/charts/boxplot.aspx
#
#
# https://machinelearningmastery.com/machine-learning-in-python-step-by-step/
#
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
#
# https://seaborn.pydata.org/introduction.html
#
#
# https://www.wintellect.com/visualizing-sales-data-in-python-with-matplotlib/
#
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial
